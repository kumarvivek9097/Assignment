# %%
from datetime import timedelta,date
from nsepy import get_history
from nsepy import get_index_pe_history
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
sbin = get_history(symbol='SBIN',
                    start=date(2015,1,1), 
                    end=date(2015,12,31))
sbin[[ 'VWAP', 'Turnover']].plot(secondary_y='Turnover')

# %%
nifty = get_history(symbol="NIFTY", 
                    start=date(2015,1,1), 
                    end=date(2015,12,31),
                    index=True)
nifty[['Close', 'Turnover']].plot(secondary_y='Turnover')

# %%
vix = get_history(symbol="INDIAVIX",
            start=date(2015,1,1),
            end=date(2015,1,10),
            index=True)

# %%
sbin_data=[]
def fun(df):
    for index, row in df.iterrows():
        for i in range(1,14):
            if index.isocalendar()[1]== 4*i:
            #print (index.strftime("%Y-%m-%d"),row['Close'])
                sbin_data.append([index.strftime("%Y-%m-%d"),row['Close']])

# %%
nifty_data=[]
def fun1(df):
    for index, row in df.iterrows():
        for i in range(1,14):
            if index.isocalendar()[1]== 4*i:
            #print (index.strftime("%Y-%m-%d"),row['Close'])
                nifty_data.append([index.strftime("%Y-%m-%d"),row['Close']])

# %%
vix_data=[]
def fun2(df):
    for index, row in df.iterrows():
        for i in range(1,14):
            if index.isocalendar()[1]== 4*i:
            #print (index.strftime("%Y-%m-%d"),row['Close'])
                vix_data.append([index.strftime("%Y-%m-%d"),row['Close']])

# %%
fun(sbin)

# %%
fun1(nifty)

# %%
short_rolling = sbin.rolling(window=10).mean()
short_rolling.head(20)
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2015-01-01   SBIN     EQ         NaN      NaN      NaN      NaN      NaN
# 2015-01-02   SBIN     EQ         NaN      NaN      NaN      NaN      NaN
# 2015-01-05   SBIN     EQ         NaN      NaN      NaN      NaN      NaN
# 2015-01-06   SBIN     EQ         NaN      NaN      NaN      NaN      NaN
# 2015-01-07   SBIN     EQ         NaN      NaN      NaN      NaN      NaN
# 2015-01-08   SBIN     EQ         NaN      NaN      NaN      NaN      NaN
# 2015-01-09   SBIN     EQ         NaN      NaN      NaN      NaN      NaN
# 2015-01-12   SBIN     EQ         NaN      NaN      NaN      NaN      NaN
# 2015-01-13   SBIN     EQ         NaN      NaN      NaN      NaN      NaN
# 2015-01-14   SBIN     EQ     307.415  308.105  310.365  304.285  306.910
# 2015-01-15   SBIN     EQ     306.700  308.850  311.235  304.615  307.350
# 2015-01-16   SBIN     EQ     307.330  309.415  311.435  304.490  307.315
# ...

# %%
long_rolling = sbin.rolling(window=75).mean()
long_rolling.head(20)
# Out:
#            Symbol Series  Prev Close  Open  High  Low  Last  Close  VWAP  \
# Date
# 2015-01-01   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-02   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-05   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-06   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-07   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-08   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-09   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-12   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-13   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-14   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-15   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# 2015-01-16   SBIN     EQ         NaN   NaN   NaN  NaN   NaN    NaN   NaN
# ...

# %%
sbin
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2015-01-01   SBIN     EQ      311.85  312.45  315.00  310.70  314.00  314.00
# 2015-01-02   SBIN     EQ      314.00  314.35  318.30  314.35  315.60  315.25
# 2015-01-05   SBIN     EQ      315.25  316.25  316.80  312.10  312.80  312.75
# 2015-01-06   SBIN     EQ      312.75  310.00  311.10  298.70  299.90  299.90
# 2015-01-07   SBIN     EQ      299.90  300.00  302.55  295.15  301.40  300.15
# 2015-01-08   SBIN     EQ      300.15  305.00  306.50  302.35  305.25  304.85
# 2015-01-09   SBIN     EQ      304.85  306.70  307.85  302.00  303.00  303.20
# 2015-01-12   SBIN     EQ      303.20  304.15  307.80  301.10  306.90  307.10
# 2015-01-13   SBIN     EQ      307.10  308.15  310.75  304.15  305.25  305.10
# 2015-01-14   SBIN     EQ      305.10  304.00  307.00  302.25  305.00  304.70
# 2015-01-15   SBIN     EQ      304.70  319.90  323.70  314.00  318.40  320.30
# ...

# %%
sbin_volume=sbin['Volume']
sbin_volume.shape[0]
# Out:
# 248

# %%
dir=[]
series=[]
for i in range(1,248):
    result=sbin_volume[i]-sbin_volume[i-1]
    result1=abs(result)
    if result1 > (0.1*sbin_volume[i-1]) or result < (0.1*sbin_volume[i-1]):
        series.append(0)
    else:
        series.append(1)
    if result>=0:
        dir.append(0)
    else: 
        dir.append(1)

# %%
sbin_close=sbin['Close']
sbin_close.shape[0]
# Out:
# 248

# %%
dir1=[]
series1=[]
for i in range(1,248):
    result2=sbin_close[i]-sbin_close[i-1]
    result3=abs(result2)
    if result1 > (0.02*sbin_close[i-1]) or result < (0.02*sbin_close[i-1]):
        series1.append(0)
    else:
        series1.append(1)
    if result2>=0:
        dir.append(0)
    else: 
        dir.append(1)
